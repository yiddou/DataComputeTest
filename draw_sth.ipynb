# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(20)
y=x^2

plt.plot(x,y)

# %%
print("haha")
# Out:
# haha

# %%
path = 'data/dummy.txt'
open(path).readline()
# Out:
# 'Hello world!'

# %%
# Out:
# week--> 1
# week2--> 202001
